# %%
import os
os.chdir("/home/mk/Denis/Word2Vec")
from vocab import Vocab
from CBOW import CBOW

f = open('./cbow/file.txt','r')
text = f.read()
f.close()
# text = 'ехал Грека через реку, видит Грека в реке рак'

model = CBOW(text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 11>()
#       8 f.close()
#       9 # text = 'ехал Грека через реку, видит Грека в реке рак'
# ---> 11 model = CBOW(text)
#
# File ~/Denis/Word2Vec/cbow/CBOW.py:22, in CBOW.__init__(self, text, embedding_size, windows_size, lr, num_epochs, batch_size, device, pretrained, tfidf)
#      20 self.optim = torch.optim.Adam(self.parameters(), lr=lr)
#      21 self.loss = nn.CrossEntropyLoss(reduction='sum')
# ---> 22 self.train(num_epochs, batch_size)
#
# File ~/Denis/Word2Vec/cbow/CBOW.py:52, in CBOW.train(self, num_epochs, batch_size)
#      50     loss = self.loss(probs, target)
#      51     loss.backward()
# ---> 52     self.optim.step()
#      54     total_loss += loss.item()
#      56 print(f'Epoch {epoch+1}, Average Loss: {total_loss / len(dataloader)}')
#
# ...
